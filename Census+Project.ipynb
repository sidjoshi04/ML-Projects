# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
pd.set_option('display.max_columns', None)

# %%
census = pd.read_csv("E:\Edrive\Sudhanshu\Datatrained Projects/scool_census_dataset.csv")

# %%
census.head()
# Out:
#    Year                Region  Gender   Age      Country New Zealand European  \
# 0    10     Wellington Region  female  14.0  New Zealand                  yes
# 1    12  Bay of Plenty Region    male  16.0  New Zealand                  yes
# 2     7       Auckland Region  female  11.0  New Zealand                   no
# 3     7        Waikato Region  female  11.0  New Zealand                  yes
# 4    13     Canterbury Region  female  17.0  New Zealand                  yes
#
#   Maori Samoan Cook Islands Maori Tongan Niuean Chinese Indian  \
# 0    no     no                 no     no     no      no     no
# 1    no     no                 no     no     no      no     no
# 2    no    yes                yes     no     no     yes     no
# 3   yes     no                 no     no     no      no     no
# 4    no     no                 no     no     no      no     no
#
#      Other ethnicity  Languages spoken Eye Colour Handedness  Height  \
# ...

# %%
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 78 columns):
# Year                                                                                        1000 non-null int64
# Region                                                                                      1000 non-null object
# Gender                                                                                      998 non-null object
# Age                                                                                         989 non-null float64
# Country                                                                                     997 non-null object
# New Zealand European                                                                        1000 non-null object
# Maori                                                                                       1000 non-null object
# ...

# %%
#Checking the Null values.
#It can be found that there are multiple columns with Null Values

# %%
census.isnull().sum()
# Out:
# Year                                                                                          0
# Region                                                                                        0
# Gender                                                                                        2
# Age                                                                                          11
# Country                                                                                       3
# New Zealand European                                                                          0
# Maori                                                                                         0
# Samoan                                                                                        0
# Cook Islands Maori                                                                            0
# Tongan                                                                                        0
# ...

# %%
#Dropping the Columns with Null values

# %%
census.drop(census.iloc[:, 64:78], axis=1, inplace=True)

# %%
census.drop(["Other ethnicity","Wrist circumference","Screen time opinion - On social media","Bag weight",
            "Bed time","Wake time","Time you get home from school","Time you ate dinner"], axis=1, inplace=True)

# %%
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 56 columns):
# Year                                         1000 non-null int64
# Region                                       1000 non-null object
# Gender                                       998 non-null object
# Age                                          989 non-null float64
# Country                                      997 non-null object
# New Zealand European                         1000 non-null object
# Maori                                        1000 non-null object
# Samoan                                       1000 non-null object
# Cook Islands Maori                           1000 non-null object
# Tongan                                       1000 non-null object
# Niuean                                       1000 non-null object
# Chinese                                      1000 non-null object
# Indian                                       1000 non-null object
# ...

# %%
census.dropna(how='all').head()
# Out:
#    Year                Region  Gender   Age      Country New Zealand European  \
# 0    10     Wellington Region  female  14.0  New Zealand                  yes
# 1    12  Bay of Plenty Region    male  16.0  New Zealand                  yes
# 2     7       Auckland Region  female  11.0  New Zealand                   no
# 3     7        Waikato Region  female  11.0  New Zealand                  yes
# 4    13     Canterbury Region  female  17.0  New Zealand                  yes
#
#   Maori Samoan Cook Islands Maori Tongan Niuean Chinese Indian  \
# 0    no     no                 no     no     no      no     no
# 1    no     no                 no     no     no      no     no
# 2    no    yes                yes     no     no     yes     no
# 3   yes     no                 no     no     no      no     no
# 4    no     no                 no     no     no      no     no
#
#    Languages spoken Eye Colour Handedness  Height  Right foot length  \
# ...

# %%
census_num= census._get_numeric_data()

# %%
census_num.head()
# Out:
#    Year   Age  Languages spoken  Height  Right foot length  \
# 0    10  14.0               2.0   164.0               25.0
# 1    12  16.0               1.0   179.0               27.0
# 2     7  11.0               1.0   165.0               24.0
# 3     7  11.0               1.0   153.0               26.0
# 4    13  17.0               1.0   166.0               26.0
#
#    Left thumb circumference  Travel time to school  Fruit/vegetables in lunch  \
# 0                       7.0                    3.0                        2.0
# 1                       7.0                   10.0                        1.0
# 2                       6.0                   15.0                        4.0
# 3                       5.0                   20.0                        2.0
# 4                       7.0                    1.0                        1.0
#
#    Memory time  Reaction time  Time standing on left leg  \
# 0         26.0          0.375                       27.0
# ...

# %%
census_obj = census.select_dtypes(include=['object'])

# %%
census_obj.head(10)
# Out:
#                  Region  Gender      Country New Zealand European Maori  \
# 0     Wellington Region  female  New Zealand                  yes    no
# 1  Bay of Plenty Region    male  New Zealand                  yes    no
# 2       Auckland Region  female  New Zealand                   no    no
# 3        Waikato Region  female  New Zealand                  yes   yes
# 4     Canterbury Region  female  New Zealand                  yes    no
# 5       Auckland Region  female  New Zealand                  yes    no
# 6       Auckland Region  female  New Zealand                   no    no
# 7          Otago Region  female  New Zealand                  yes    no
# 8     Canterbury Region  female  New Zealand                  yes    no
# 9     Wellington Region  female  New Zealand                  yes    no
#
#   Samoan Cook Islands Maori Tongan Niuean Chinese Indian Eye Colour  \
# 0     no                 no     no     no      no     no       blue
# ...

# %%
census["Physical activity - before school"] = census["Physical activity - before school"].str.split('+').str[0]

# %%
census["Physical activity - at school"] = census["Physical activity - at school"].str.split('+').str[0]

# %%
census["Physical activity - after school"] = census["Physical activity - after school"].str.split('+').str[0]

# %%
census.head(5)
# Out:
#    Year                Region  Gender   Age      Country New Zealand European  \
# 0    10     Wellington Region  female  14.0  New Zealand                  yes
# 1    12  Bay of Plenty Region    male  16.0  New Zealand                  yes
# 2     7       Auckland Region  female  11.0  New Zealand                   no
# 3     7        Waikato Region  female  11.0  New Zealand                  yes
# 4    13     Canterbury Region  female  17.0  New Zealand                  yes
#
#   Maori Samoan Cook Islands Maori Tongan Niuean Chinese Indian  \
# 0    no     no                 no     no     no      no     no
# 1    no     no                 no     no     no      no     no
# 2    no    yes                yes     no     no     yes     no
# 3   yes     no                 no     no     no      no     no
# 4    no     no                 no     no     no      no     no
#
#    Languages spoken Eye Colour Handedness  Height  Right foot length  \
# ...

# %%
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 56 columns):
# Year                                         1000 non-null int64
# Region                                       1000 non-null object
# Gender                                       998 non-null object
# Age                                          989 non-null float64
# Country                                      997 non-null object
# New Zealand European                         1000 non-null object
# Maori                                        1000 non-null object
# Samoan                                       1000 non-null object
# Cook Islands Maori                           1000 non-null object
# Tongan                                       1000 non-null object
# Niuean                                       1000 non-null object
# Chinese                                      1000 non-null object
# Indian                                       1000 non-null object
# ...

# %%
census["Physical activity - before school"] = pd.to_numeric(census["Physical activity - before school"],errors='coerce')

# %%
census["Physical activity - at school"] = pd.to_numeric(census["Physical activity - at school"],errors='coerce')

# %%
census["Physical activity - after school"] = pd.to_numeric(census["Physical activity - after school"],errors='coerce')

# %%
census_num= census._get_numeric_data()

# %%
census_num.head()
# Out:
#    Year   Age  Languages spoken  Height  Right foot length  \
# 0    10  14.0               2.0   164.0               25.0
# 1    12  16.0               1.0   179.0               27.0
# 2     7  11.0               1.0   165.0               24.0
# 3     7  11.0               1.0   153.0               26.0
# 4    13  17.0               1.0   166.0               26.0
#
#    Left thumb circumference  Travel time to school  Fruit/vegetables in lunch  \
# 0                       7.0                    3.0                        2.0
# 1                       7.0                   10.0                        1.0
# 2                       6.0                   15.0                        4.0
# 3                       5.0                   20.0                        2.0
# 4                       7.0                    1.0                        1.0
#
#    Memory time  Reaction time  Time standing on left leg  \
# 0         26.0          0.375                       27.0
# ...

# %%
census_num.isnull().sum()
# Out:
# Year                                   0
# Age                                   11
# Languages spoken                      49
# Height                                36
# Right foot length                     26
# Left thumb circumference              61
# Travel time to school                 19
# Fruit/vegetables in lunch             21
# Memory time                           19
# Reaction time                         29
# Time standing on left leg             26
# Physical activity - before school     70
# Physical activity - at school         52
# Physical activity - after school      33
# Physical activity - on the weekend    48
# Scheduled activities in last week     36
# Screen time after school              84
# Sleep time                            25
# dtype: int64

# %%
census_num.fillna(census_num.mean(), inplace = True)
# Out:
#      Year   Age  Languages spoken     Height  Right foot length  \
# 0      10  14.0          2.000000  164.00000               25.0
# 1      12  16.0          1.000000  179.00000               27.0
# 2       7  11.0          1.000000  165.00000               24.0
# 3       7  11.0          1.000000  153.00000               26.0
# 4      13  17.0          1.000000  166.00000               26.0
# 5       9  13.0          1.000000  155.00000               24.0
# 6      10  14.0          2.000000  159.00000               24.0
# 7      11  15.0          1.000000  164.00000               24.0
# 8       8  12.0          1.000000  167.00000               24.0
# 9      10  14.0          1.000000  168.00000               21.0
# 10      7  11.0          2.000000  148.00000               22.0
# 11      5   8.0          2.000000  139.00000               22.0
# 12     10  14.0          1.000000  179.00000               31.0
# 13      9  13.0          4.000000  148.00000               18.0
# ...

# %%
census_num.isnull().sum()
# Out:
# Year                                  0
# Age                                   0
# Languages spoken                      0
# Height                                0
# Right foot length                     0
# Left thumb circumference              0
# Travel time to school                 0
# Fruit/vegetables in lunch             0
# Memory time                           0
# Reaction time                         0
# Time standing on left leg             0
# Physical activity - before school     0
# Physical activity - at school         0
# Physical activity - after school      0
# Physical activity - on the weekend    0
# Scheduled activities in last week     0
# Screen time after school              0
# Sleep time                            0
# dtype: int64

# %%
census_obj = census.select_dtypes(include=['object'])

# %%
census_obj.head()
# Out:
#                  Region  Gender      Country New Zealand European Maori  \
# 0     Wellington Region  female  New Zealand                  yes    no
# 1  Bay of Plenty Region    male  New Zealand                  yes    no
# 2       Auckland Region  female  New Zealand                   no    no
# 3        Waikato Region  female  New Zealand                  yes   yes
# 4     Canterbury Region  female  New Zealand                  yes    no
#
#   Samoan Cook Islands Maori Tongan Niuean Chinese Indian Eye Colour  \
# 0     no                 no     no     no      no     no       blue
# 1     no                 no     no     no      no     no       blue
# 2    yes                yes     no     no     yes     no      brown
# 3     no                 no     no     no      no     no      brown
# 4     no                 no     no     no      no     no      brown
#
#   Handedness Travel method to school Litter in lunch Favourite video game  \
# ...

# %%
census_obj.isnull().sum()
# Out:
# Region                                        0
# Gender                                        2
# Country                                       3
# New Zealand European                          0
# Maori                                         0
# Samoan                                        0
# Cook Islands Maori                            0
# Tongan                                        0
# Niuean                                        0
# Chinese                                       0
# Indian                                        0
# Eye Colour                                    0
# Handedness                                    6
# Travel method to school                       8
# Litter in lunch                              13
# Favourite video game                         77
# Own cell phone                               13
# Facebook account                             13
# Instagram account                            13
# Snapchat account                             13
# ...

# %%
census_obj = census_obj.drop(['Favourite video game'], axis=1)

# %%
census_obj.head()
# Out:
#                  Region  Gender      Country New Zealand European Maori  \
# 0     Wellington Region  female  New Zealand                  yes    no
# 1  Bay of Plenty Region    male  New Zealand                  yes    no
# 2       Auckland Region  female  New Zealand                   no    no
# 3        Waikato Region  female  New Zealand                  yes   yes
# 4     Canterbury Region  female  New Zealand                  yes    no
#
#   Samoan Cook Islands Maori Tongan Niuean Chinese Indian Eye Colour  \
# 0     no                 no     no     no      no     no       blue
# 1     no                 no     no     no      no     no       blue
# 2    yes                yes     no     no     yes     no      brown
# 3     no                 no     no     no      no     no      brown
# 4     no                 no     no     no      no     no      brown
#
#   Handedness Travel method to school Litter in lunch Own cell phone  \
# ...

# %%
census_new = pd.concat([census_num,census_obj],axis=1)

# %%
census_new.head(5)
# Out:
#    Year   Age  Languages spoken  Height  Right foot length  \
# 0    10  14.0               2.0   164.0               25.0
# 1    12  16.0               1.0   179.0               27.0
# 2     7  11.0               1.0   165.0               24.0
# 3     7  11.0               1.0   153.0               26.0
# 4    13  17.0               1.0   166.0               26.0
#
#    Left thumb circumference  Travel time to school  Fruit/vegetables in lunch  \
# 0                       7.0                    3.0                        2.0
# 1                       7.0                   10.0                        1.0
# 2                       6.0                   15.0                        4.0
# 3                       5.0                   20.0                        2.0
# 4                       7.0                    1.0                        1.0
#
#    Memory time  Reaction time  Time standing on left leg  \
# 0         26.0          0.375                       27.0
# ...

# %%
census_new = census_new.dropna()

# %%
census_new.shape
# Out:
# (884, 55)

# %%
census_new.head(20)
# Out:
#     Year   Age  Languages spoken  Height  Right foot length  \
# 0     10  14.0          2.000000   164.0               25.0
# 1     12  16.0          1.000000   179.0               27.0
# 4     13  17.0          1.000000   166.0               26.0
# 5      9  13.0          1.000000   155.0               24.0
# 6     10  14.0          2.000000   159.0               24.0
# 7     11  15.0          1.000000   164.0               24.0
# 8      8  12.0          1.000000   167.0               24.0
# 9     10  14.0          1.000000   168.0               21.0
# 10     7  11.0          2.000000   148.0               22.0
# 11     5   8.0          2.000000   139.0               22.0
# 12    10  14.0          1.000000   179.0               31.0
# 13     9  13.0          4.000000   148.0               18.0
# 14     8  12.0          1.000000   151.0               21.0
# 17     8  13.0          2.000000   157.0               23.0
# 18     6  11.0          1.000000   153.0               22.0
# ...

# %%
census_new = census_new.replace('n/a', np.nan)

# %%
census_new.isnull().sum()
# Out:
# Year                                           0
# Age                                            0
# Languages spoken                               0
# Height                                         0
# Right foot length                              0
# Left thumb circumference                       0
# Travel time to school                          0
# Fruit/vegetables in lunch                      0
# Memory time                                    0
# Reaction time                                  0
# Time standing on left leg                      0
# Physical activity - before school              0
# Physical activity - at school                  0
# Physical activity - after school               0
# Physical activity - on the weekend             0
# Scheduled activities in last week              0
# Screen time after school                       0
# Sleep time                                     0
# Region                                         0
# ...

# %%
census_new = census_new.drop(["Check messages as soon as you wake up", "Respond to messages immediately", "Take phone to school",
                              "Lose focus as school due to phone", "Screen time opinion - On your phone"],axis=1)

# %%
census_new.shape
# Out:
# (884, 50)

# %%
census_new.head(10)
# Out:
#     Year   Age  Languages spoken  Height  Right foot length  \
# 0     10  14.0               2.0   164.0               25.0
# 1     12  16.0               1.0   179.0               27.0
# 4     13  17.0               1.0   166.0               26.0
# 5      9  13.0               1.0   155.0               24.0
# 6     10  14.0               2.0   159.0               24.0
# 7     11  15.0               1.0   164.0               24.0
# 8      8  12.0               1.0   167.0               24.0
# 9     10  14.0               1.0   168.0               21.0
# 10     7  11.0               2.0   148.0               22.0
# 11     5   8.0               2.0   139.0               22.0
#
#     Left thumb circumference  Travel time to school  \
# 0                   7.000000                    3.0
# 1                   7.000000                   10.0
# 4                   7.000000                    1.0
# 5                   6.000000                   63.0
# ...

# %%
#Year are Highly correlated with Height, Age, Memory Time, Physical activity - at school, Sleep Time 
#Age is Highly correlated with Height, Memory Time, Physical activity - at school, Sleep Time
#Height is Highly correlated with Memory Time, Physical activity - at school, Sleep Time
#Travel time to school and Sleep Time are correlated
#Fruit/vegetables in lunch and Screen time after school are correlated
#Physical activity - at school and Screen time after school are correlated
#Physical activity - on the weekend and Screen time after school are correlated

# %%
correlation = census_new.corr()
plt.figure(figsize=(14,14))
sns.heatmap(census_new.corr(), annot=True)

# %%
# There are more Female students than Male

# %%
census_new['Gender'].value_counts().plot.bar()

# %%
# There are few Foreign Students in the School, Most foreign students are from Australia and England

# %%
census_new['Country'].value_counts().plot.bar()

# %%
# Most students are between 9 to 15

# %%
sns.swarmplot(x = 'Gender', y = 'Age', data = census_new)

# %%
# Students coming from West Coast Region are spending a lot of time in Travelling to school

# %%
sns.boxplot(x = 'Travel time to school', y = 'Region', data = census_new)

# %%
# Most of the students spends less than 20 in Travelling to school

# %%
sns.distplot(census_new['Travel time to school'], kde=False)
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Most students sleep between 7 to 11 Hours

# %%
sns.distplot(census_new['Sleep time'], kde=False)
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(census_new['Height'], kde=False, bins=10)

# %%
#Most students use Motor to reach school

# %%
census_new['Travel method to school'].value_counts().plot.bar()

# %%
census_new['Own cell phone'].value_counts().plot.bar()

# %%
# Female owns Cell phone more than Male

# %%
sns.countplot(y='Own cell phone', hue='Gender', data=census_new)

# %%
# Most of the student play games on Mobile

# %%
census_new['Screen time opinion - Playing video games'].value_counts().plot.bar()

# %%
# Only few students has a Youtube channel and are on Facebook

# %%
census_new['YouTube channel'].value_counts().plot.bar()

# %%
census_new['Facebook account'].value_counts().plot.bar()

# %%
# Most of the students think Climate change is Urgent

# %%
census_new['Climate change opinion'].value_counts().plot.bar()
